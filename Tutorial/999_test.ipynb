# %%
pip install tpot2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tpot2
#   Downloading TPOT2-0.1.2a0-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 1.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: xgboost>=1.7.0 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (1.7.6)
# Collecting baikal>=0.4.2
#   Downloading baikal-0.4.2-py3-none-any.whl (34 kB)
# Requirement already satisfied: joblib>=1.1.1 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (1.3.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (1.3.0)
# Collecting jupyter>=1.0.0
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting traitlets>=5.8.0
#   Using cached traitlets-5.9.0-py3-none-any.whl (117 kB)
# Collecting matplotlib>=3.6.2
#   Downloading matplotlib-3.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 16.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: func-timeout>=4.3.5 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (4.3.5)
# Collecting dask>=2023.3.1
#   Downloading dask-2023.8.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting dask-ml>=2022.5.27
#   Downloading dask_ml-2023.3.24-py3-none-any.whl (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.7/148.7 KB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: optuna>=3.0.5 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (3.3.0)
# Collecting dask-jobqueue>=0.8.1
#   Downloading dask_jobqueue-0.8.2-py2.py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 KB 4.3 MB/s eta 0:00:00
# Collecting stopit>=1.1.1
#   Downloading stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16.3 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (1.25.2)
# Collecting distributed>=2023.3.1
#   Downloading distributed-2023.8.1-py3-none-any.whl (990 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.5/990.5 KB 12.7 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting update-checker>=0.16
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Collecting pandas<2.0.0,>=1.5.3
#   Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 19.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: tqdm>=4.36.1 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (4.65.2)
# Requirement already satisfied: networkx>=3.0 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (3.1)
# Requirement already satisfied: scipy>=1.3.1 in /usr/lib/python3/dist-packages (from tpot2) (1.8.0)
# Requirement already satisfied: lightgbm>=3.3.3 in /home/jay/.local/lib/python3.10/site-packages (from tpot2) (4.0.0)
# Collecting importlib-metadata>=4.13.0
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting fsspec>=2021.09.0
#   Using cached fsspec-2023.6.0-py3-none-any.whl (163 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from dask>=2023.3.1->tpot2) (21.3)
# Collecting toolz>=0.10.0
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle>=1.5.0 in /home/jay/.local/lib/python3.10/site-packages (from dask>=2023.3.1->tpot2) (2.2.1)
# Collecting partd>=1.2.0
#   Downloading partd-1.4.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3/dist-packages (from dask>=2023.3.1->tpot2) (5.4.1)
# Requirement already satisfied: click>=8.0 in /usr/lib/python3/dist-packages (from dask>=2023.3.1->tpot2) (8.0.3)
# Collecting dask-glm>=0.2.0
#   Downloading dask_glm-0.2.0-py2.py3-none-any.whl (12 kB)
# Collecting multipledispatch>=0.4.9
#   Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Collecting numba>=0.51.0
#   Downloading numba-0.57.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 17.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: tornado>=6.0.4 in /usr/lib/python3/dist-packages (from distributed>=2023.3.1->tpot2) (6.1)
# Collecting zict>=2.2.0
#   Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 KB 4.5 MB/s eta 0:00:00
# Collecting tblib>=1.6.0
#   Downloading tblib-2.0.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: psutil>=5.7.2 in /home/jay/.local/lib/python3.10/site-packages (from distributed>=2023.3.1->tpot2) (5.9.5)
# Collecting sortedcontainers>=2.0.5
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting locket>=1.0.0
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/lib/python3/dist-packages (from distributed>=2023.3.1->tpot2) (3.0.3)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/lib/python3/dist-packages (from distributed>=2023.3.1->tpot2) (1.0.3)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/lib/python3/dist-packages (from distributed>=2023.3.1->tpot2) (1.26.5)
# Requirement already satisfied: ipywidgets in /usr/lib/python3/dist-packages (from jupyter>=1.0.0->tpot2) (6.0.0)
# Requirement already satisfied: ipykernel in /usr/lib/python3/dist-packages (from jupyter>=1.0.0->tpot2) (6.7.0)
# Collecting qtconsole
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 KB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: notebook in /usr/lib/python3/dist-packages (from jupyter>=1.0.0->tpot2) (6.4.8)
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: nbconvert in /usr/lib/python3/dist-packages (from jupyter>=1.0.0->tpot2) (6.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.2->tpot2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.2->tpot2) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/jay/.local/lib/python3.10/site-packages (from matplotlib>=3.6.2->tpot2) (10.0.0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.7/300.7 KB 6.4 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /home/jay/.local/lib/python3.10/site-packages (from matplotlib>=3.6.2->tpot2) (2.8.2)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.2->tpot2) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.6.2->tpot2) (4.29.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/jay/.local/lib/python3.10/site-packages (from optuna>=3.0.5->tpot2) (2.0.20)
# Requirement already satisfied: alembic>=1.5.0 in /home/jay/.local/lib/python3.10/site-packages (from optuna>=3.0.5->tpot2) (1.11.3)
# Requirement already satisfied: colorlog in /home/jay/.local/lib/python3.10/site-packages (from optuna>=3.0.5->tpot2) (6.7.0)
# Requirement already satisfied: cmaes>=0.10.0 in /home/jay/.local/lib/python3.10/site-packages (from optuna>=3.0.5->tpot2) (0.10.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas<2.0.0,>=1.5.3->tpot2) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jay/.local/lib/python3.10/site-packages (from scikit-learn>=1.2.0->tpot2) (3.2.0)
# Requirement already satisfied: requests>=2.3.0 in /usr/lib/python3/dist-packages (from update-checker>=0.16->tpot2) (2.25.1)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.0.5->tpot2) (1.1.3)
# Requirement already satisfied: typing-extensions>=4 in /home/jay/.local/lib/python3.10/site-packages (from alembic>=1.5.0->optuna>=3.0.5->tpot2) (4.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata>=4.13.0->dask>=2023.3.1->tpot2) (1.0.0)
# Collecting llvmlite<0.41,>=0.40.0dev0
#   Downloading llvmlite-0.40.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 11.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting numpy>=1.16.3
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 12.8 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6.2->tpot2) (1.16.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/lib/python3/dist-packages (from sqlalchemy>=1.3.0->optuna>=3.0.5->tpot2) (1.1.2)
# Collecting debugpy<2.0,>=1.0.0
#   Using cached debugpy-1.6.7.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Requirement already satisfied: pyzmq>=17 in /usr/lib/python3/dist-packages (from jupyter-console->jupyter>=1.0.0->tpot2) (22.3.0)
# Collecting jupyter-core!=5.0.*,>=4.12
#   Using cached jupyter_core-5.3.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: ipython in /usr/lib/python3/dist-packages (from jupyter-console->jupyter>=1.0.0->tpot2) (7.31.1)
# Requirement already satisfied: pygments in /home/jay/.local/lib/python3.10/site-packages (from jupyter-console->jupyter>=1.0.0->tpot2) (2.16.1)
# Collecting ipykernel
#   Using cached ipykernel-6.25.1-py3-none-any.whl (154 kB)
# Collecting prompt-toolkit>=3.0.30
#   Using cached prompt_toolkit-3.0.39-py3-none-any.whl (385 kB)
# Requirement already satisfied: jupyter-client>=7.0.0 in /usr/lib/python3/dist-packages (from jupyter-console->jupyter>=1.0.0->tpot2) (7.1.2)
# Collecting comm>=0.1.1
#   Using cached comm-0.1.4-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/lib/python3/dist-packages (from ipykernel->jupyter>=1.0.0->tpot2) (0.1.3)
# Requirement already satisfied: nest-asyncio in /usr/lib/python3/dist-packages (from ipykernel->jupyter>=1.0.0->tpot2) (1.5.4)
# Collecting qtpy>=2.0.1
#   Downloading QtPy-2.4.0-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 KB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: ipython-genutils in /usr/lib/python3/dist-packages (from qtconsole->jupyter>=1.0.0->tpot2) (0.2.0)
# Collecting platformdirs>=2.5
#   Using cached platformdirs-3.10.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: wcwidth in /usr/lib/python3/dist-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter>=1.0.0->tpot2) (0.2.5)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11956 sha256=25964eb7dcf1f9bf070f56de1c195d446547ff41d5027ba94ca47f5deabfc623
#   Stored in directory: /home/jay/.cache/pip/wheels/af/f9/87/bf5b3d565c2a007b4dae9d8142dccc85a9f164e517062dd519
# Successfully built stopit
# Installing collected packages: stopit, sortedcontainers, multipledispatch, zict, update-checker, traitlets, toolz, tblib, qtpy, prompt-toolkit, platformdirs, numpy, locket, llvmlite, importlib-metadata, fsspec, debugpy, partd, pandas, numba, jupyter-core, contourpy, comm, baikal, matplotlib, ipykernel, dask, qtconsole, jupyter-console, distributed, jupyter, dask-jobqueue, dask-glm, dask-ml, tpot2
#   WARNING: The script qtpy is installed in '/home/jay/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   WARNING: The scripts f2py, f2py3 and f2py3.10 are installed in '/home/jay/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.0
#     Uninstalling pandas-2.1.0:
#       Successfully uninstalled pandas-2.1.0
#   WARNING: The scripts jupyter, jupyter-migrate and jupyter-troubleshoot are installed in '/home/jay/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script dask is installed in '/home/jay/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jupyter-console is installed in '/home/jay/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts dask-scheduler, dask-ssh and dask-worker are installed in '/home/jay/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tpot2 is installed in '/home/jay/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed baikal-0.4.2 comm-0.1.4 contourpy-1.1.0 dask-2023.8.1 dask-glm-0.2.0 dask-jobqueue-0.8.2 dask-ml-2023.3.24 debugpy-1.6.7.post1 distributed-2023.8.1 fsspec-2023.6.0 importlib-metadata-6.8.0 ipykernel-6.25.1 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-core-5.3.1 llvmlite-0.40.1 locket-1.0.0 matplotlib-3.7.2 multipledispatch-1.0.0 numba-0.57.1 numpy-1.24.4 pandas-1.5.3 partd-1.4.0 platformdirs-3.10.0 prompt-toolkit-3.0.39 qtconsole-5.4.3 qtpy-2.4.0 sortedcontainers-2.4.0 stopit-1.1.2 tblib-2.0.0 toolz-0.12.0 tpot2-0.1.2a0 traitlets-5.9.0 update-checker-0.18.0 zict-3.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tpot2
import pandas as pd
import numpy as np
#make a dataframe with columns a,b,c,d,e,f

#numpy array where columns are 1,2,3,4,5,6
data = np.repeat([np.arange(6)],10,0)

df = pd.DataFrame(data,columns=['a','b','c','d','e','f'])
fss = tpot2.builtin_modules.FeatureSetSelector(name='test',sel_subset=['a','b','c'])

print("original DataFrame")
print(df)
print("Transformed Data")
print(fss.fit_transform(df))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_46991/660658468.py in <module>
# ----> 1 import tpot2
#       2 import pandas as pd
#       3 import numpy as np
#       4 #make a dataframe with columns a,b,c,d,e,f
#       5
#
# ~/.local/lib/python3.10/site-packages/tpot2/__init__.py in <module>
#       3 #TODO clean up import organization
#       4 from ._version import __version__
# ----> 5 from .graphsklearn import *
#       6 from .individual import *
#       7 from .logbook import *
#
# ~/.local/lib/python3.10/site-packages/tpot2/graphsklearn.py in <module>
#       3 import networkx as nx
#       4
# ----> 5 import matplotlib.pyplot as plt
#       6 import sklearn
#       7 from sklearn.utils.metaestimators import available_if
#
# ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py in <module>
#      59 from matplotlib.backend_bases import (
#      60     FigureCanvasBase, FigureManagerBase, MouseButton)
# ---> 61 from matplotlib.figure import Figure, FigureBase, figaspect
#      62 from matplotlib.gridspec import GridSpec, SubplotSpec
#      63 from matplotlib import rcParams, rcParamsDefault, get_backend, rcParamsOrig
#
# ~/.local/lib/python3.10/site-packages/matplotlib/figure.py in <module>
#      41
#      42 import matplotlib as mpl
# ---> 43 from matplotlib import _blocking_input, backend_bases, _docstring, projections
#      44 from matplotlib.artist import (
#      45     Artist, allow_rasterization, _finalize_rasterization)
#
# ~/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py in <module>
#      56 from .geo import AitoffAxes, HammerAxes, LambertAxes, MollweideAxes
#      57 from .polar import PolarAxes
# ---> 58 from mpl_toolkits.mplot3d import Axes3D
#      59
#      60
#
# /usr/lib/python3/dist-packages/mpl_toolkits/mplot3d/__init__.py in <module>
# ----> 1 from .axes3d import Axes3D
#
# /usr/lib/python3/dist-packages/mpl_toolkits/mplot3d/axes3d.py in <module>
#      32 import matplotlib.container as mcontainer
#      33 import matplotlib.transforms as mtransforms
# ---> 34 from matplotlib.axes import Axes, rcParams
#      35 from matplotlib.axes._base import _axis_method_wrapper, _process_plot_format
#      36 from matplotlib.transforms import Bbox
#
# ImportError: cannot import name 'rcParams' from 'matplotlib.axes' (/home/jay/.local/lib/python3.10/site-packages/matplotlib/axes/__init__.py)
